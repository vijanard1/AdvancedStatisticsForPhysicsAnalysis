# %% [markdown]
# Refer to stat_06_handout2.pdf and another notes in which the first exercise is solved as an example
#
# Ex1 =  straight forward Poisson's distribution
#
# > It is a Poisson's distribution with 'mu' parameter
#
# >dt = 10s
#
# >number of particles emitted in consecutive intervals is : 4, 1, 3, 1, 3
#
# Ex2 = joint probability distribution
#
# Ex3= signal and prob distribution

# %%
# ggplot2 examples
library(ggplot2)
# Out:
# Registered S3 methods overwritten by 'tibble':
#   method     from
#   format.tbl pillar
#   print.tbl  pillar
#
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# (a)
# The distribution is given as 4, 1, 3, 1, 3. The time interval between samples is 10s
#
# We have to determine the 'mu' of the distribution
#
# ${P} = {{(} {\lambda} {t} {)}^n \exp ^{{-}{\lambda}{t}} }{\div} n {!} $
#
# $ t = 10s, 20s, 30s, 40s, 50s $
#
# $ N(t) = 4, 1, 3, 1, 3 $
#
# $ From {\space} these {\space} numbers {\space} we {\space} have {\space} {\lambda} = 2.2 $

# %% [markdown]
# Determine the $\lambda$ through R code
# Using the reference https://stats.stackexchange.com/questions/390321/how-to-calculate-the-parameter-lambda-in-poisson-distribution

# %%
install.packages('MASS')
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
library('MASS')

# %%
a <- c(4,1,3,1,3)
MASS::fitdistr(a,"Poisson")
# Out:
#     lambda
#   2.4000000
#  (0.6928203)

# %%
for(r in seq(from=0, to=10, by=2)) {
    
    p.star <- dbinom (x=r, size=n, prob=p)

    p.norm <- p.star /( delta.p*sum(p.star ))

    plot(p, p.norm , type="l", lwd=1.5, col='navy',

         xlim=c(0,1), ylim=c(0,1.1*max(p.norm )),
         xaxs="i", yaxs="i", xlab="p", ylab="P(p | r,n,M)")
    
    title (main=paste("r =",r), line=0.3, cex.main=1.2)
    
    p.mean <- delta.p*sum(p*p.norm)
    
    abline (v=p.mean , lty=2)
}
# Out:
# Plot with title “r = 0”
# Plot with title “r = 2”
# Plot with title “r = 4”
# Plot with title “r = 6”
# Plot with title “r = 8”
# Plot with title “r = 10”
